# %% [markdown]
# # Selective Search Segmentation

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
from source import Hierarchical
import source

# %% [markdown]
# Read image

# %%
img=cv2.imread('Images/Figure10.jpg')
img=img[:,:,::-1]
# %matplotlib inline
plt.imshow(img)
plt.show()

# %%
ssearch=Hierarchical(img,file_name='result3.txt')
print('Number of components in after initial merging: {}'.format(len(ssearch.list_comp)))
# Out:
# Set up for Selective Search ...
# Retrieving components from result3.txt ...
# Finding components neighbors ...
# Starting initial merge ...
# Set up the gradiant image ...
# Thresholding each channel ...
# compute color similarity ...
# Compute texture similarity ...
# Compute size similarity ...
# Compute fill similarity ...
# Number of components in after initial merging: 616

# %% [markdown]
# Let's see in each gradiant image

# %%
for idx,image in enumerate(ssearch.texture_sim.img_grad):
    if(idx%2==0):
        print('Gradiant image {}'.format(idx))
        # %matplotlib inline
        plt.imshow(image)
        plt.show()
# Out:
# Gradiant image 0
# Gradiant image 2
# Gradiant image 4
# Gradiant image 6
# Gradiant image 8
# Gradiant image 10
# Gradiant image 12
# Gradiant image 14
# Gradiant image 16
# Gradiant image 18
# Gradiant image 20
# Gradiant image 22

# %% [markdown]
# Visualize the first segmented image

# %%
segmented_img=source.initial_segment(ssearch.list_comp,(img.shape[0],img.shape[1]))
segmented_img=segmented_img[:,:,::-1]
# %matplotlib inline
plt.imshow(segmented_img)
plt.show()

# %% [markdown]
# Merge the similar components, i did many stages to archive this.
#
# **Stage 1:**

# %%
ssearch.merge_regions(strategy=(0,0,1,0),img_area=img.shape[0]*img.shape[1],nregions=50)
# Out:
# Merge for 1 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 2 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 3 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 4 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 5 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 6 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 7 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# ...

# %%
print('Number of regions after merging: {}'.format(len(ssearch.list_comp)))
# Out:
# Number of regions after merging: 566

# %%
segmented_img=source.initial_segment(ssearch.list_comp,(img.shape[0],img.shape[1]))
segmented_img=segmented_img[:,:,::-1]
# %matplotlib inline
plt.imshow(segmented_img)
plt.show()

# %% [markdown]
# **Stage 2:**

# %%
ssearch.merge_regions(strategy=(0,0,0,1),img_area=img.shape[0]*img.shape[1],nregions=200)
# Out:
# Merge for 1 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 2 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 3 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 4 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 5 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 6 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 7 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# ...

# %%
print('Number of regions after merging {}'.format(len(ssearch.list_comp)))
# Out:
# Number of regions after merging 366

# %% [markdown]
# Visualize the result again

# %%
segmented_img=source.initial_segment(ssearch.list_comp,(img.shape[0],img.shape[1]))
segmented_img=segmented_img[:,:,::-1]
# %matplotlib inline
plt.imshow(segmented_img)
plt.show()

# %% [markdown]
# **Stage 3:**

# %%
ssearch.merge_regions(strategy=(1,1,0,0),img_area=img.shape[0]*img.shape[0],nregions=150)
# Out:
# Merge for 1 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 2 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 3 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 4 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 5 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 6 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 7 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# ...

# %%
print('Number of regions after merging {}'.format(len(ssearch.list_comp)))
# Out:
# Number of regions after merging 216

# %%
segmented_img=source.initial_segment(ssearch.list_comp,(img.shape[0],img.shape[1]))
segmented_img=segmented_img[:,:,::-1]
# %matplotlib inline
plt.imshow(segmented_img)
plt.show()

# %% [markdown]
# **Stage 4:**

# %%
ssearch.merge_regions(strategy=(1,0,1,0),img_area=img.shape[0]*img.shape[0],nregions=150)
# Out:
# Merge for 1 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 2 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 3 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 4 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 5 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 6 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 7 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# ...

# %%
print('Number of regions after merging {}'.format(len(ssearch.list_comp)))
# Out:
# Number of regions after merging 66

# %%
segmented_img=source.initial_segment(ssearch.list_comp,(img.shape[0],img.shape[1]))
segmented_img=segmented_img[:,:,::-1]
# %matplotlib inline
plt.imshow(segmented_img)
plt.show()

# %%
ssearch.merge_regions(strategy=(1,0,1,1),img_area=img.shape[0]*img.shape[0],nregions=30)
# Out:
# Merge for 1 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 2 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 3 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 4 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 5 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 6 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# Update Fill similarity ...
# Merge for 7 regions ...
# Update Color Histogram ...
# Update texture similarity ...
# Update Size similarity ...
# ...

# %%
print('Number of regions after merging {}'.format(len(ssearch.list_comp)))
# Out:
# Number of regions after merging 36

# %%
segmented_img=source.initial_segment(ssearch.list_comp,(img.shape[0],img.shape[1]))
segmented_img=segmented_img[:,:,::-1]
# %matplotlib inline
plt.imshow(segmented_img)
plt.show()

# %% [markdown]
# The result is not so perfect. (may be the setup for the algorithm is not good)
